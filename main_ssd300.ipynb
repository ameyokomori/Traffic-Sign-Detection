# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from keras.utils import plot_model
from math import ceil
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from data_generator.data_augmentation_chain_variable_input_size import DataAugmentationVariableInputSize

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
img_height = 300 # Height of the model input images
img_width = 400 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 43 # Number of positive classes
scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = 'models/VGG_ILSVRC_16_layers_fc_reduced.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# TODO: Set the path to the `.h5` file of the model to be loaded.
model_path = 'ssd300.h5'

# We need to create an SSDLoss object in order to pass that to the model loader.
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

K.clear_session() # Clear previous models from memory.

model = load_model(model_path, custom_objects={'AnchorBoxes': AnchorBoxes,
                                               'L2Normalization': L2Normalization,
                                               'compute_loss': ssd_loss.compute_loss})

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.

# The directories that contain the images.
images_dir = 'data/Full/'

# The directories that contain the annotations.
train_labels_filename = 'data/train.txt'
val_labels_filename   = 'data/test.txt'


train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'ymin', 'xmax', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'ymin', 'xmax', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07+12_trainval.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)
# Out:
# Loading images into memory: 100%|██████████| 666/666 [00:02<00:00, 227.00it/s]
# Loading images into memory: 100%|██████████| 75/75 [00:00<00:00, 218.98it/s]
# Creating HDF5 dataset: 100%|██████████| 666/666 [00:05<00:00, 118.66it/s]
# Creating HDF5 dataset: 100%|██████████| 75/75 [00:00<00:00, 118.74it/s]

# %%
# 3: Set the batch size.

batch_size = 16 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.

# For the training generator:
ssd_data_augmentation = DataAugmentationVariableInputSize(resize_height=img_height,
                                                          resize_width=img_width,
                                                          random_brightness=(-48, 48, 0.5),
                                                          random_contrast=(0.5, 1.8, 0.5),
                                                          random_saturation=(0.5, 1.8, 0.5),
                                                          background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	   666
# Number of images in the validation dataset:	    75

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='ssd300.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename='ssd300_pascal_07+12_training_log.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=50,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.1,
                                         patience=20,
                                         verbose=1,
                                         epsilon=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)

callbacks = [model_checkpoint,
             csv_logger,
             reduce_learning_rate,
             early_stopping]
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/callbacks.py:1065: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 30
final_epoch     = 500
steps_per_epoch = ceil(train_dataset_size/batch_size)

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 31/500
# 42/42 [==============================] - 95s 2s/step - loss: 7.3575 - val_loss: 6.4498
#
# Epoch 00031: val_loss improved from inf to 6.44984, saving model to ssd300.h5
# Epoch 32/500
# 42/42 [==============================] - 62s 1s/step - loss: 7.2912 - val_loss: 6.2626
#
# Epoch 00032: val_loss improved from 6.44984 to 6.26255, saving model to ssd300.h5
# Epoch 33/500
# 42/42 [==============================] - 67s 2s/step - loss: 7.3166 - val_loss: 6.0695
#
# Epoch 00033: val_loss improved from 6.26255 to 6.06950, saving model to ssd300.h5
# Epoch 34/500
# 42/42 [==============================] - 70s 2s/step - loss: 7.2951 - val_loss: 5.8936
#
# Epoch 00034: val_loss improved from 6.06950 to 5.89359, saving model to ssd300.h5
# Epoch 35/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.9048 - val_loss: 5.9342
#
# Epoch 00035: val_loss did not improve from 5.89359
# Epoch 36/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.9197 - val_loss: 5.8334
#
# Epoch 00036: val_loss improved from 5.89359 to 5.83340, saving model to ssd300.h5
# Epoch 37/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.7728 - val_loss: 5.9119
#
# Epoch 00037: val_loss did not improve from 5.83340
# Epoch 38/500
# 42/42 [==============================] - 70s 2s/step - loss: 9.5959 - val_loss: 8.2910
#
# Epoch 00038: val_loss did not improve from 5.83340
# Epoch 39/500
# 42/42 [==============================] - 68s 2s/step - loss: 8.7731 - val_loss: 6.9744
#
# Epoch 00039: val_loss did not improve from 5.83340
# Epoch 40/500
# 42/42 [==============================] - 70s 2s/step - loss: 7.6703 - val_loss: 6.6122
#
# Epoch 00040: val_loss did not improve from 5.83340
# Epoch 41/500
# 42/42 [==============================] - 70s 2s/step - loss: 7.3939 - val_loss: 6.2181
#
# Epoch 00041: val_loss did not improve from 5.83340
# Epoch 42/500
# 42/42 [==============================] - 72s 2s/step - loss: 7.1896 - val_loss: 6.1412
#
# Epoch 00042: val_loss did not improve from 5.83340
# Epoch 43/500
# 42/42 [==============================] - 71s 2s/step - loss: 7.0414 - val_loss: 5.9257
#
# Epoch 00043: val_loss did not improve from 5.83340
# Epoch 44/500
# 42/42 [==============================] - 70s 2s/step - loss: 7.0653 - val_loss: 6.0732
#
# Epoch 00044: val_loss did not improve from 5.83340
# Epoch 45/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.8755 - val_loss: 6.1052
#
# Epoch 00045: val_loss did not improve from 5.83340
# Epoch 46/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.9979 - val_loss: 5.8992
#
# Epoch 00046: val_loss did not improve from 5.83340
# Epoch 47/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.8132 - val_loss: 5.4875
#
# Epoch 00047: val_loss improved from 5.83340 to 5.48750, saving model to ssd300.h5
# Epoch 48/500
# 42/42 [==============================] - 72s 2s/step - loss: 6.6473 - val_loss: 5.5717
#
# Epoch 00048: val_loss did not improve from 5.48750
# Epoch 49/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.5445 - val_loss: 5.7677
#
# Epoch 00049: val_loss did not improve from 5.48750
# Epoch 50/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.6216 - val_loss: 5.6081
#
# Epoch 00050: val_loss did not improve from 5.48750
# Epoch 51/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.7187 - val_loss: 5.5486
#
# Epoch 00051: val_loss did not improve from 5.48750
# Epoch 52/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.5024 - val_loss: 5.6502
#
# Epoch 00052: val_loss did not improve from 5.48750
# Epoch 53/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.4886 - val_loss: 5.4413
#
# Epoch 00053: val_loss improved from 5.48750 to 5.44128, saving model to ssd300.h5
# Epoch 54/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.1854 - val_loss: 5.3086
#
# Epoch 00054: val_loss improved from 5.44128 to 5.30862, saving model to ssd300.h5
# Epoch 55/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.3852 - val_loss: 5.3930
#
# Epoch 00055: val_loss did not improve from 5.30862
# Epoch 56/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.4655 - val_loss: 5.4323
#
# Epoch 00056: val_loss did not improve from 5.30862
# Epoch 57/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.2700 - val_loss: 5.0807
#
# Epoch 00057: val_loss improved from 5.30862 to 5.08070, saving model to ssd300.h5
# Epoch 58/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.3360 - val_loss: 5.2432
#
# Epoch 00058: val_loss did not improve from 5.08070
# Epoch 59/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.2847 - val_loss: 5.3032
#
# Epoch 00059: val_loss did not improve from 5.08070
# Epoch 60/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.1686 - val_loss: 5.2212
#
# Epoch 00060: val_loss did not improve from 5.08070
# Epoch 61/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.3451 - val_loss: 5.3930
#
# Epoch 00061: val_loss did not improve from 5.08070
# Epoch 62/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.3090 - val_loss: 5.1937
#
# Epoch 00062: val_loss did not improve from 5.08070
# Epoch 63/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.2669 - val_loss: 5.3440
#
# Epoch 00063: val_loss did not improve from 5.08070
# Epoch 64/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.4931 - val_loss: 5.4655
#
# Epoch 00064: val_loss did not improve from 5.08070
# Epoch 65/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.4777 - val_loss: 5.1071
#
# Epoch 00065: val_loss did not improve from 5.08070
# Epoch 66/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.1931 - val_loss: 5.0838
#
# Epoch 00066: val_loss did not improve from 5.08070
# Epoch 67/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.9895 - val_loss: 5.0547
#
# Epoch 00067: val_loss improved from 5.08070 to 5.05466, saving model to ssd300.h5
# Epoch 68/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.9589 - val_loss: 5.0294
#
# Epoch 00068: val_loss improved from 5.05466 to 5.02941, saving model to ssd300.h5
# Epoch 69/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.0481 - val_loss: 4.9922
#
# Epoch 00069: val_loss improved from 5.02941 to 4.99216, saving model to ssd300.h5
# Epoch 70/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.2622 - val_loss: 5.9489
#
# Epoch 00070: val_loss did not improve from 4.99216
# Epoch 71/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.0741 - val_loss: 5.2417
#
# Epoch 00071: val_loss did not improve from 4.99216
# Epoch 72/500
# 42/42 [==============================] - 72s 2s/step - loss: 6.2606 - val_loss: 5.1439
#
# Epoch 00072: val_loss did not improve from 4.99216
# Epoch 73/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.9624 - val_loss: 5.1281
#
# Epoch 00073: val_loss did not improve from 4.99216
# Epoch 74/500
# 42/42 [==============================] - 70s 2s/step - loss: 6.0593 - val_loss: 5.1588
#
# Epoch 00074: val_loss did not improve from 4.99216
# Epoch 75/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.9684 - val_loss: 5.0500
#
# Epoch 00075: val_loss did not improve from 4.99216
# Epoch 76/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.6938 - val_loss: 5.2228
#
# Epoch 00076: val_loss did not improve from 4.99216
# Epoch 77/500
# 42/42 [==============================] - 72s 2s/step - loss: 6.0165 - val_loss: 4.9552
#
# Epoch 00077: val_loss improved from 4.99216 to 4.95518, saving model to ssd300.h5
# Epoch 78/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.8824 - val_loss: 5.0321
#
# Epoch 00078: val_loss did not improve from 4.95518
# Epoch 79/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.8486 - val_loss: 4.9746
#
# Epoch 00079: val_loss did not improve from 4.95518
# Epoch 80/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.9964 - val_loss: 5.1119
#
# Epoch 00080: val_loss did not improve from 4.95518
# Epoch 81/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.9132 - val_loss: 5.0962
#
# Epoch 00081: val_loss did not improve from 4.95518
# Epoch 82/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.9732 - val_loss: 4.9507
#
# Epoch 00082: val_loss improved from 4.95518 to 4.95069, saving model to ssd300.h5
# Epoch 83/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.9940 - val_loss: 4.8380
#
# Epoch 00083: val_loss improved from 4.95069 to 4.83803, saving model to ssd300.h5
# Epoch 84/500
# 42/42 [==============================] - 73s 2s/step - loss: 5.7477 - val_loss: 4.8949
#
# Epoch 00084: val_loss did not improve from 4.83803
# Epoch 85/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6233 - val_loss: 4.9508
#
# Epoch 00085: val_loss did not improve from 4.83803
# Epoch 86/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6830 - val_loss: 4.8443
#
# Epoch 00086: val_loss did not improve from 4.83803
# Epoch 87/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.8286 - val_loss: 4.9859
#
# Epoch 00087: val_loss did not improve from 4.83803
# Epoch 88/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.1317 - val_loss: 5.5278
#
# Epoch 00088: val_loss did not improve from 4.83803
# Epoch 89/500
# 42/42 [==============================] - 69s 2s/step - loss: 6.0902 - val_loss: 5.0696
#
# Epoch 00089: val_loss did not improve from 4.83803
# Epoch 90/500
# 42/42 [==============================] - 71s 2s/step - loss: 6.2045 - val_loss: 5.1687
#
# Epoch 00090: val_loss did not improve from 4.83803
# Epoch 91/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.8150 - val_loss: 5.0829
#
# Epoch 00091: val_loss did not improve from 4.83803
# Epoch 92/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.8923 - val_loss: 4.6831
#
# Epoch 00092: val_loss improved from 4.83803 to 4.68313, saving model to ssd300.h5
# Epoch 93/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6450 - val_loss: 4.8076
#
# Epoch 00093: val_loss did not improve from 4.68313
# Epoch 94/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.5485 - val_loss: 4.8647
#
# Epoch 00094: val_loss did not improve from 4.68313
# Epoch 95/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.6867 - val_loss: 5.0986
#
# Epoch 00095: val_loss did not improve from 4.68313
# Epoch 96/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.9146 - val_loss: 4.9630
#
# Epoch 00096: val_loss did not improve from 4.68313
# Epoch 97/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6095 - val_loss: 4.9979
#
# Epoch 00097: val_loss did not improve from 4.68313
# Epoch 98/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.8074 - val_loss: 4.7617
#
# Epoch 00098: val_loss did not improve from 4.68313
# Epoch 99/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.5559 - val_loss: 4.9982
#
# Epoch 00099: val_loss did not improve from 4.68313
# Epoch 100/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4872 - val_loss: 4.7100
#
# Epoch 00100: val_loss did not improve from 4.68313
# Epoch 101/500
# 42/42 [==============================] - 68s 2s/step - loss: 5.5050 - val_loss: 4.8373
#
# Epoch 00101: val_loss did not improve from 4.68313
# Epoch 102/500
# 42/42 [==============================] - 73s 2s/step - loss: 5.4549 - val_loss: 4.8951
#
# Epoch 00102: val_loss did not improve from 4.68313
# Epoch 103/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6437 - val_loss: 4.6571
#
# Epoch 00103: val_loss improved from 4.68313 to 4.65713, saving model to ssd300.h5
# Epoch 104/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.5761 - val_loss: 4.6935
#
# Epoch 00104: val_loss did not improve from 4.65713
# Epoch 105/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.4841 - val_loss: 4.7592
#
# Epoch 00105: val_loss did not improve from 4.65713
# Epoch 106/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.7546 - val_loss: 4.7505
#
# Epoch 00106: val_loss did not improve from 4.65713
# Epoch 107/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4767 - val_loss: 4.7716
#
# Epoch 00107: val_loss did not improve from 4.65713
# Epoch 108/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.3660 - val_loss: 4.5729
#
# Epoch 00108: val_loss improved from 4.65713 to 4.57293, saving model to ssd300.h5
# Epoch 109/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.5177 - val_loss: 4.8372
#
# Epoch 00109: val_loss did not improve from 4.57293
# Epoch 110/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.5619 - val_loss: 4.6917
#
# Epoch 00110: val_loss did not improve from 4.57293
# Epoch 111/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.3322 - val_loss: 4.9039
#
# Epoch 00111: val_loss did not improve from 4.57293
# Epoch 112/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.2066 - val_loss: 4.7738
#
# Epoch 00112: val_loss did not improve from 4.57293
# Epoch 113/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.5243 - val_loss: 4.6235
#
# Epoch 00113: val_loss did not improve from 4.57293
# Epoch 114/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.5291 - val_loss: 4.8539
#
# Epoch 00114: val_loss did not improve from 4.57293
# Epoch 115/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.5336 - val_loss: 4.7927
#
# Epoch 00115: val_loss did not improve from 4.57293
# Epoch 116/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.4823 - val_loss: 4.7299
#
# Epoch 00116: val_loss did not improve from 4.57293
# Epoch 117/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4540 - val_loss: 4.8254
#
# Epoch 00117: val_loss did not improve from 4.57293
# Epoch 118/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.3282 - val_loss: 4.9043
#
# Epoch 00118: val_loss did not improve from 4.57293
# Epoch 119/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.4455 - val_loss: 4.8371
#
# Epoch 00119: val_loss did not improve from 4.57293
# Epoch 120/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.5217 - val_loss: 4.6873
#
# Epoch 00120: val_loss did not improve from 4.57293
# Epoch 121/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.2331 - val_loss: 4.6419
#
# Epoch 00121: val_loss did not improve from 4.57293
# Epoch 122/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.3779 - val_loss: 4.4983
#
# Epoch 00122: val_loss improved from 4.57293 to 4.49833, saving model to ssd300.h5
# Epoch 123/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.2423 - val_loss: 4.4202
#
# Epoch 00123: val_loss improved from 4.49833 to 4.42018, saving model to ssd300.h5
# Epoch 124/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.3270 - val_loss: 4.6600
#
# Epoch 00124: val_loss did not improve from 4.42018
# Epoch 125/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.9694 - val_loss: 4.7670
#
# Epoch 00125: val_loss did not improve from 4.42018
# Epoch 126/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.4710 - val_loss: 4.6853
#
# Epoch 00126: val_loss did not improve from 4.42018
# Epoch 127/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.3681 - val_loss: 4.6021
#
# Epoch 00127: val_loss did not improve from 4.42018
# Epoch 128/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4226 - val_loss: 4.7523
#
# Epoch 00128: val_loss did not improve from 4.42018
# Epoch 129/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4557 - val_loss: 4.8376
#
# Epoch 00129: val_loss did not improve from 4.42018
# Epoch 130/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.4666 - val_loss: 4.7478
#
# Epoch 00130: val_loss did not improve from 4.42018
# Epoch 131/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.6525 - val_loss: 4.8691
#
# Epoch 00131: val_loss did not improve from 4.42018
# Epoch 132/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4831 - val_loss: 4.7189
#
# Epoch 00132: val_loss did not improve from 4.42018
# Epoch 133/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.3750 - val_loss: 4.6871
#
# Epoch 00133: val_loss did not improve from 4.42018
# Epoch 134/500
# 42/42 [==============================] - 68s 2s/step - loss: 5.3392 - val_loss: 4.6583
#
# Epoch 00134: val_loss did not improve from 4.42018
# Epoch 135/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.3217 - val_loss: 4.7988
#
# Epoch 00135: val_loss did not improve from 4.42018
# Epoch 136/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.3513 - val_loss: 4.9233
#
# Epoch 00136: val_loss did not improve from 4.42018
# Epoch 137/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4029 - val_loss: 4.7058
#
# Epoch 00137: val_loss did not improve from 4.42018
# Epoch 138/500
# 42/42 [==============================] - 72s 2s/step - loss: 5.3182 - val_loss: 4.6514
#
# Epoch 00138: val_loss did not improve from 4.42018
# Epoch 139/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.2566 - val_loss: 4.6687
#
# Epoch 00139: val_loss did not improve from 4.42018
# Epoch 140/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.3616 - val_loss: 4.9155
#
# Epoch 00140: val_loss did not improve from 4.42018
# Epoch 141/500
# 42/42 [==============================] - 71s 2s/step - loss: 5.4897 - val_loss: 4.6536
#
# Epoch 00141: val_loss did not improve from 4.42018
# Epoch 142/500
# 42/42 [==============================] - 69s 2s/step - loss: 5.4354 - val_loss: 4.5459
#
# Epoch 00142: val_loss did not improve from 4.42018
# Epoch 143/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.4693 - val_loss: 4.8167
#
# Epoch 00143: val_loss did not improve from 4.42018
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 144/500
# 42/42 [==============================] - 70s 2s/step - loss: 5.1692 - val_loss: 4.4242
#
# Epoch 00144: val_loss did not improve from 4.42018
# Epoch 145/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.7315 - val_loss: 4.3010
#
# Epoch 00145: val_loss improved from 4.42018 to 4.30102, saving model to ssd300.h5
# Epoch 146/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.9109 - val_loss: 4.3028
#
# Epoch 00146: val_loss did not improve from 4.30102
# Epoch 147/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.8404 - val_loss: 4.2754
#
# Epoch 00147: val_loss improved from 4.30102 to 4.27540, saving model to ssd300.h5
# Epoch 148/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.7459 - val_loss: 4.2726
#
# Epoch 00148: val_loss improved from 4.27540 to 4.27264, saving model to ssd300.h5
# Epoch 149/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.7691 - val_loss: 4.1990
#
# Epoch 00149: val_loss improved from 4.27264 to 4.19898, saving model to ssd300.h5
# Epoch 150/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.6876 - val_loss: 4.1196
#
# Epoch 00150: val_loss improved from 4.19898 to 4.11959, saving model to ssd300.h5
# Epoch 151/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.6831 - val_loss: 4.1497
#
# Epoch 00151: val_loss did not improve from 4.11959
# Epoch 152/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.7691 - val_loss: 4.1310
#
# Epoch 00152: val_loss did not improve from 4.11959
# Epoch 153/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.8092 - val_loss: 4.0947
#
# Epoch 00153: val_loss improved from 4.11959 to 4.09466, saving model to ssd300.h5
# Epoch 154/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.5663 - val_loss: 4.1281
#
# Epoch 00154: val_loss did not improve from 4.09466
# Epoch 155/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.7977 - val_loss: 4.1737
#
# Epoch 00155: val_loss did not improve from 4.09466
# Epoch 156/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.7303 - val_loss: 4.0918
#
# Epoch 00156: val_loss improved from 4.09466 to 4.09182, saving model to ssd300.h5
# Epoch 157/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.7377 - val_loss: 4.1234
#
# Epoch 00157: val_loss did not improve from 4.09182
# Epoch 158/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.7007 - val_loss: 4.0688
#
# Epoch 00158: val_loss improved from 4.09182 to 4.06879, saving model to ssd300.h5
# Epoch 159/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.6038 - val_loss: 4.0902
#
# Epoch 00159: val_loss did not improve from 4.06879
# Epoch 160/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.7592 - val_loss: 4.0816
#
# Epoch 00160: val_loss did not improve from 4.06879
# Epoch 161/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.6687 - val_loss: 4.1586
#
# Epoch 00161: val_loss did not improve from 4.06879
# Epoch 162/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.5411 - val_loss: 4.0617
#
# Epoch 00162: val_loss improved from 4.06879 to 4.06170, saving model to ssd300.h5
# Epoch 163/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.6380 - val_loss: 4.1339
#
# Epoch 00163: val_loss did not improve from 4.06170
# Epoch 164/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5401 - val_loss: 4.0987
#
# Epoch 00164: val_loss did not improve from 4.06170
# Epoch 165/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.4985 - val_loss: 4.0708
#
# Epoch 00165: val_loss did not improve from 4.06170
# Epoch 166/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5534 - val_loss: 4.0488
#
# Epoch 00166: val_loss improved from 4.06170 to 4.04878, saving model to ssd300.h5
# Epoch 167/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.6959 - val_loss: 4.0894
#
# Epoch 00167: val_loss did not improve from 4.04878
# Epoch 168/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5689 - val_loss: 4.0162
#
# Epoch 00168: val_loss improved from 4.04878 to 4.01617, saving model to ssd300.h5
# Epoch 169/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.5718 - val_loss: 4.1282
#
# Epoch 00169: val_loss did not improve from 4.01617
# Epoch 170/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5992 - val_loss: 4.0494
#
# Epoch 00170: val_loss did not improve from 4.01617
# Epoch 171/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.6469 - val_loss: 4.0389
#
# Epoch 00171: val_loss did not improve from 4.01617
# Epoch 172/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.4313 - val_loss: 4.0518
#
# Epoch 00172: val_loss did not improve from 4.01617
# Epoch 173/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5094 - val_loss: 4.0258
#
# Epoch 00173: val_loss did not improve from 4.01617
# Epoch 174/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.5573 - val_loss: 4.0863
#
# Epoch 00174: val_loss did not improve from 4.01617
# Epoch 175/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.7811 - val_loss: 4.0704
#
# Epoch 00175: val_loss did not improve from 4.01617
# Epoch 176/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3666 - val_loss: 3.9956
#
# Epoch 00176: val_loss improved from 4.01617 to 3.99558, saving model to ssd300.h5
# Epoch 177/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3486 - val_loss: 3.9531
#
# Epoch 00177: val_loss improved from 3.99558 to 3.95306, saving model to ssd300.h5
# Epoch 178/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3908 - val_loss: 4.0567
#
# Epoch 00178: val_loss did not improve from 3.95306
# Epoch 179/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.6129 - val_loss: 4.0410
#
# Epoch 00179: val_loss did not improve from 3.95306
# Epoch 180/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.4255 - val_loss: 4.0214
#
# Epoch 00180: val_loss did not improve from 3.95306
# Epoch 181/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.4026 - val_loss: 3.9723
#
# Epoch 00181: val_loss did not improve from 3.95306
# Epoch 182/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.4314 - val_loss: 3.9642
#
# Epoch 00182: val_loss did not improve from 3.95306
# Epoch 183/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.4353 - val_loss: 3.9241
#
# Epoch 00183: val_loss improved from 3.95306 to 3.92409, saving model to ssd300.h5
# Epoch 184/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.5060 - val_loss: 3.9678
#
# Epoch 00184: val_loss did not improve from 3.92409
# Epoch 185/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.3978 - val_loss: 3.9799
#
# Epoch 00185: val_loss did not improve from 3.92409
# Epoch 186/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.5931 - val_loss: 3.8799
#
# Epoch 00186: val_loss improved from 3.92409 to 3.87994, saving model to ssd300.h5
# Epoch 187/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.4880 - val_loss: 3.8536
#
# Epoch 00187: val_loss improved from 3.87994 to 3.85361, saving model to ssd300.h5
# Epoch 188/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.4007 - val_loss: 3.9100
#
# Epoch 00188: val_loss did not improve from 3.85361
# Epoch 189/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.5385 - val_loss: 3.8860
#
# Epoch 00189: val_loss did not improve from 3.85361
# Epoch 190/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3119 - val_loss: 3.8850
#
# Epoch 00190: val_loss did not improve from 3.85361
# Epoch 191/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3204 - val_loss: 3.8415
#
# Epoch 00191: val_loss improved from 3.85361 to 3.84145, saving model to ssd300.h5
# Epoch 192/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3475 - val_loss: 3.9310
#
# Epoch 00192: val_loss did not improve from 3.84145
# Epoch 193/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3207 - val_loss: 3.8821
#
# Epoch 00193: val_loss did not improve from 3.84145
# Epoch 194/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.3982 - val_loss: 3.9035
#
# Epoch 00194: val_loss did not improve from 3.84145
# Epoch 195/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2265 - val_loss: 3.8174
#
# Epoch 00195: val_loss improved from 3.84145 to 3.81738, saving model to ssd300.h5
# Epoch 196/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.3078 - val_loss: 3.9050
#
# Epoch 00196: val_loss did not improve from 3.81738
# Epoch 197/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2568 - val_loss: 3.9721
#
# Epoch 00197: val_loss did not improve from 3.81738
# Epoch 198/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.3126 - val_loss: 3.9248
#
# Epoch 00198: val_loss did not improve from 3.81738
# Epoch 199/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2776 - val_loss: 3.9387
#
# Epoch 00199: val_loss did not improve from 3.81738
# Epoch 200/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2468 - val_loss: 3.9024
#
# Epoch 00200: val_loss did not improve from 3.81738
# Epoch 201/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.4709 - val_loss: 3.8815
#
# Epoch 00201: val_loss did not improve from 3.81738
# Epoch 202/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.4375 - val_loss: 3.8900
#
# Epoch 00202: val_loss did not improve from 3.81738
# Epoch 203/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2457 - val_loss: 3.8887
#
# Epoch 00203: val_loss did not improve from 3.81738
# Epoch 204/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2549 - val_loss: 3.9009
#
# Epoch 00204: val_loss did not improve from 3.81738
# Epoch 205/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.3027 - val_loss: 3.8747
#
# Epoch 00205: val_loss did not improve from 3.81738
# Epoch 206/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.3816 - val_loss: 3.8170
#
# Epoch 00206: val_loss improved from 3.81738 to 3.81700, saving model to ssd300.h5
# Epoch 207/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3466 - val_loss: 3.8285
#
# Epoch 00207: val_loss did not improve from 3.81700
# Epoch 208/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2551 - val_loss: 3.9484
#
# Epoch 00208: val_loss did not improve from 3.81700
# Epoch 209/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.5246 - val_loss: 3.9381
#
# Epoch 00209: val_loss did not improve from 3.81700
# Epoch 210/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2958 - val_loss: 3.9333
#
# Epoch 00210: val_loss did not improve from 3.81700
# Epoch 211/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2522 - val_loss: 3.9138
#
# Epoch 00211: val_loss did not improve from 3.81700
# Epoch 212/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0945 - val_loss: 3.9129
#
# Epoch 00212: val_loss did not improve from 3.81700
# Epoch 213/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3395 - val_loss: 3.8481
#
# Epoch 00213: val_loss did not improve from 3.81700
# Epoch 214/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3176 - val_loss: 3.8668
#
# Epoch 00214: val_loss did not improve from 3.81700
# Epoch 215/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2568 - val_loss: 3.8674
#
# Epoch 00215: val_loss did not improve from 3.81700
#
# Epoch 00215: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 216/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1409 - val_loss: 3.8254
#
# Epoch 00216: val_loss did not improve from 3.81700
# Epoch 217/500
# 42/42 [==============================] - 67s 2s/step - loss: 4.1107 - val_loss: 3.8170
#
# Epoch 00217: val_loss improved from 3.81700 to 3.81700, saving model to ssd300.h5
# Epoch 218/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.0620 - val_loss: 3.8057
#
# Epoch 00218: val_loss improved from 3.81700 to 3.80568, saving model to ssd300.h5
# Epoch 219/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2758 - val_loss: 3.7908
#
# Epoch 00219: val_loss improved from 3.80568 to 3.79075, saving model to ssd300.h5
# Epoch 220/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2259 - val_loss: 3.7893
#
# Epoch 00220: val_loss improved from 3.79075 to 3.78926, saving model to ssd300.h5
# Epoch 221/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2895 - val_loss: 3.7929
#
# Epoch 00221: val_loss did not improve from 3.78926
# Epoch 222/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1916 - val_loss: 3.7837
#
# Epoch 00222: val_loss improved from 3.78926 to 3.78373, saving model to ssd300.h5
# Epoch 223/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1496 - val_loss: 3.8051
#
# Epoch 00223: val_loss did not improve from 3.78373
# Epoch 224/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1645 - val_loss: 3.8003
#
# Epoch 00224: val_loss did not improve from 3.78373
# Epoch 225/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1175 - val_loss: 3.7973
#
# Epoch 00225: val_loss did not improve from 3.78373
# Epoch 226/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1409 - val_loss: 3.7832
#
# Epoch 00226: val_loss improved from 3.78373 to 3.78317, saving model to ssd300.h5
# Epoch 227/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0679 - val_loss: 3.7926
#
# Epoch 00227: val_loss did not improve from 3.78317
# Epoch 228/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1585 - val_loss: 3.7850
#
# Epoch 00228: val_loss did not improve from 3.78317
# Epoch 229/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1417 - val_loss: 3.7902
#
# Epoch 00229: val_loss did not improve from 3.78317
# Epoch 230/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1763 - val_loss: 3.7817
#
# Epoch 00230: val_loss improved from 3.78317 to 3.78174, saving model to ssd300.h5
# Epoch 231/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0811 - val_loss: 3.7821
#
# Epoch 00231: val_loss did not improve from 3.78174
# Epoch 232/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9888 - val_loss: 3.7912
#
# Epoch 00232: val_loss did not improve from 3.78174
# Epoch 233/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1121 - val_loss: 3.8122
#
# Epoch 00233: val_loss did not improve from 3.78174
# Epoch 234/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2093 - val_loss: 3.8025
#
# Epoch 00234: val_loss did not improve from 3.78174
# Epoch 235/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1012 - val_loss: 3.7911
#
# Epoch 00235: val_loss did not improve from 3.78174
# Epoch 236/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1246 - val_loss: 3.8070
#
# Epoch 00236: val_loss did not improve from 3.78174
# Epoch 237/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2219 - val_loss: 3.8023
#
# Epoch 00237: val_loss did not improve from 3.78174
# Epoch 238/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0532 - val_loss: 3.7918
#
# Epoch 00238: val_loss did not improve from 3.78174
# Epoch 239/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.1308 - val_loss: 3.7849
#
# Epoch 00239: val_loss did not improve from 3.78174
# Epoch 240/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0325 - val_loss: 3.7771
#
# Epoch 00240: val_loss improved from 3.78174 to 3.77711, saving model to ssd300.h5
# Epoch 241/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.3122 - val_loss: 3.7799
#
# Epoch 00241: val_loss did not improve from 3.77711
# Epoch 242/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1089 - val_loss: 3.7804
#
# Epoch 00242: val_loss did not improve from 3.77711
# Epoch 243/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0882 - val_loss: 3.7764
#
# Epoch 00243: val_loss improved from 3.77711 to 3.77641, saving model to ssd300.h5
# Epoch 244/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3361 - val_loss: 3.7774
#
# Epoch 00244: val_loss did not improve from 3.77641
# Epoch 245/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2130 - val_loss: 3.7660
#
# Epoch 00245: val_loss improved from 3.77641 to 3.76596, saving model to ssd300.h5
# Epoch 246/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2414 - val_loss: 3.7824
#
# Epoch 00246: val_loss did not improve from 3.76596
# Epoch 247/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1429 - val_loss: 3.7765
#
# Epoch 00247: val_loss did not improve from 3.76596
# Epoch 248/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0805 - val_loss: 3.7755
#
# Epoch 00248: val_loss did not improve from 3.76596
# Epoch 249/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2667 - val_loss: 3.7948
#
# Epoch 00249: val_loss did not improve from 3.76596
# Epoch 250/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2824 - val_loss: 3.7953
#
# Epoch 00250: val_loss did not improve from 3.76596
# Epoch 251/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0656 - val_loss: 3.7786
#
# Epoch 00251: val_loss did not improve from 3.76596
# Epoch 252/500
# 42/42 [==============================] - 73s 2s/step - loss: 4.0677 - val_loss: 3.7575
#
# Epoch 00252: val_loss improved from 3.76596 to 3.75749, saving model to ssd300.h5
# Epoch 253/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0962 - val_loss: 3.7538
#
# Epoch 00253: val_loss improved from 3.75749 to 3.75381, saving model to ssd300.h5
# Epoch 254/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0019 - val_loss: 3.7593
#
# Epoch 00254: val_loss did not improve from 3.75381
# Epoch 255/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2226 - val_loss: 3.7677
#
# Epoch 00255: val_loss did not improve from 3.75381
# Epoch 256/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2001 - val_loss: 3.7811
#
# Epoch 00256: val_loss did not improve from 3.75381
# Epoch 257/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.2370 - val_loss: 3.7683
#
# Epoch 00257: val_loss did not improve from 3.75381
# Epoch 258/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1092 - val_loss: 3.7687
#
# Epoch 00258: val_loss did not improve from 3.75381
# Epoch 259/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0514 - val_loss: 3.7781
#
# Epoch 00259: val_loss did not improve from 3.75381
# Epoch 260/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1761 - val_loss: 3.7654
#
# Epoch 00260: val_loss did not improve from 3.75381
# Epoch 261/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1976 - val_loss: 3.7540
#
# Epoch 00261: val_loss did not improve from 3.75381
# Epoch 262/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2567 - val_loss: 3.7563
#
# Epoch 00262: val_loss did not improve from 3.75381
# Epoch 263/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0925 - val_loss: 3.7588
#
# Epoch 00263: val_loss did not improve from 3.75381
# Epoch 264/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0445 - val_loss: 3.7610
#
# Epoch 00264: val_loss did not improve from 3.75381
# Epoch 265/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1972 - val_loss: 3.7740
#
# Epoch 00265: val_loss did not improve from 3.75381
# Epoch 266/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9371 - val_loss: 3.7801
#
# Epoch 00266: val_loss did not improve from 3.75381
# Epoch 267/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2204 - val_loss: 3.7801
#
# Epoch 00267: val_loss did not improve from 3.75381
# Epoch 268/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2044 - val_loss: 3.7720
#
# Epoch 00268: val_loss did not improve from 3.75381
# Epoch 269/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1691 - val_loss: 3.7728
#
# Epoch 00269: val_loss did not improve from 3.75381
# Epoch 270/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1734 - val_loss: 3.7655
#
# Epoch 00270: val_loss did not improve from 3.75381
# Epoch 271/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2889 - val_loss: 3.7704
#
# Epoch 00271: val_loss did not improve from 3.75381
# Epoch 272/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9030 - val_loss: 3.7700
#
# Epoch 00272: val_loss did not improve from 3.75381
# Epoch 273/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1227 - val_loss: 3.7613
#
# Epoch 00273: val_loss did not improve from 3.75381
#
# Epoch 00273: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 274/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1186 - val_loss: 3.7667
#
# Epoch 00274: val_loss did not improve from 3.75381
# Epoch 275/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9551 - val_loss: 3.7758
#
# Epoch 00275: val_loss did not improve from 3.75381
# Epoch 276/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1411 - val_loss: 3.7636
#
# Epoch 00276: val_loss did not improve from 3.75381
# Epoch 277/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1596 - val_loss: 3.7532
#
# Epoch 00277: val_loss improved from 3.75381 to 3.75315, saving model to ssd300.h5
# Epoch 278/500
# 42/42 [==============================] - 73s 2s/step - loss: 4.2431 - val_loss: 3.7684
#
# Epoch 00278: val_loss did not improve from 3.75315
# Epoch 279/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0179 - val_loss: 3.7570
#
# Epoch 00279: val_loss did not improve from 3.75315
# Epoch 280/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1192 - val_loss: 3.7568
#
# Epoch 00280: val_loss did not improve from 3.75315
# Epoch 281/500
# 42/42 [==============================] - 67s 2s/step - loss: 4.0303 - val_loss: 3.7520
#
# Epoch 00281: val_loss improved from 3.75315 to 3.75198, saving model to ssd300.h5
# Epoch 282/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0333 - val_loss: 3.7379
#
# Epoch 00282: val_loss improved from 3.75198 to 3.73787, saving model to ssd300.h5
# Epoch 283/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1302 - val_loss: 3.7381
#
# Epoch 00283: val_loss did not improve from 3.73787
# Epoch 284/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0869 - val_loss: 3.7364
#
# Epoch 00284: val_loss improved from 3.73787 to 3.73638, saving model to ssd300.h5
# Epoch 285/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0018 - val_loss: 3.7258
#
# Epoch 00285: val_loss improved from 3.73638 to 3.72583, saving model to ssd300.h5
# Epoch 286/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.2598 - val_loss: 3.7246
#
# Epoch 00286: val_loss improved from 3.72583 to 3.72458, saving model to ssd300.h5
# Epoch 287/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9791 - val_loss: 3.7217
#
# Epoch 00287: val_loss improved from 3.72458 to 3.72172, saving model to ssd300.h5
# Epoch 288/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0060 - val_loss: 3.7373
#
# Epoch 00288: val_loss did not improve from 3.72172
# Epoch 289/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9673 - val_loss: 3.7441
#
# Epoch 00289: val_loss did not improve from 3.72172
# Epoch 290/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9827 - val_loss: 3.7597
#
# Epoch 00290: val_loss did not improve from 3.72172
# Epoch 291/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.3295 - val_loss: 3.7612
#
# Epoch 00291: val_loss did not improve from 3.72172
# Epoch 292/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1008 - val_loss: 3.7429
#
# Epoch 00292: val_loss did not improve from 3.72172
# Epoch 293/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0452 - val_loss: 3.7399
#
# Epoch 00293: val_loss did not improve from 3.72172
# Epoch 294/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0664 - val_loss: 3.7417
#
# Epoch 00294: val_loss did not improve from 3.72172
# Epoch 295/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1321 - val_loss: 3.7433
#
# Epoch 00295: val_loss did not improve from 3.72172
# Epoch 296/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0158 - val_loss: 3.7490
#
# Epoch 00296: val_loss did not improve from 3.72172
# Epoch 297/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9091 - val_loss: 3.7494
#
# Epoch 00297: val_loss did not improve from 3.72172
# Epoch 298/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0643 - val_loss: 3.7384
#
# Epoch 00298: val_loss did not improve from 3.72172
# Epoch 299/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0600 - val_loss: 3.7385
#
# Epoch 00299: val_loss did not improve from 3.72172
# Epoch 300/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9307 - val_loss: 3.7336
#
# Epoch 00300: val_loss did not improve from 3.72172
# Epoch 301/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1467 - val_loss: 3.7466
#
# Epoch 00301: val_loss did not improve from 3.72172
# Epoch 302/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1159 - val_loss: 3.7257
#
# Epoch 00302: val_loss did not improve from 3.72172
# Epoch 303/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1520 - val_loss: 3.7189
#
# Epoch 00303: val_loss improved from 3.72172 to 3.71894, saving model to ssd300.h5
# Epoch 304/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1432 - val_loss: 3.7398
#
# Epoch 00304: val_loss did not improve from 3.71894
# Epoch 305/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2354 - val_loss: 3.7352
#
# Epoch 00305: val_loss did not improve from 3.71894
# Epoch 306/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.2994 - val_loss: 3.7408
#
# Epoch 00306: val_loss did not improve from 3.71894
# Epoch 307/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1409 - val_loss: 3.7313
#
# Epoch 00307: val_loss did not improve from 3.71894
# Epoch 308/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1579 - val_loss: 3.7221
#
# Epoch 00308: val_loss did not improve from 3.71894
# Epoch 309/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9769 - val_loss: 3.7483
#
# Epoch 00309: val_loss did not improve from 3.71894
# Epoch 310/500
# 42/42 [==============================] - 73s 2s/step - loss: 4.1374 - val_loss: 3.7414
#
# Epoch 00310: val_loss did not improve from 3.71894
# Epoch 311/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.2287 - val_loss: 3.7553
#
# Epoch 00311: val_loss did not improve from 3.71894
# Epoch 312/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1549 - val_loss: 3.7464
#
# Epoch 00312: val_loss did not improve from 3.71894
# Epoch 313/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0143 - val_loss: 3.7240
#
# Epoch 00313: val_loss did not improve from 3.71894
# Epoch 314/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0581 - val_loss: 3.7490
#
# Epoch 00314: val_loss did not improve from 3.71894
# Epoch 315/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1049 - val_loss: 3.7181
#
# Epoch 00315: val_loss improved from 3.71894 to 3.71810, saving model to ssd300.h5
# Epoch 316/500
# 42/42 [==============================] - 68s 2s/step - loss: 4.1160 - val_loss: 3.7346
#
# Epoch 00316: val_loss did not improve from 3.71810
# Epoch 317/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9744 - val_loss: 3.7203
#
# Epoch 00317: val_loss did not improve from 3.71810
# Epoch 318/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1964 - val_loss: 3.7217
#
# Epoch 00318: val_loss did not improve from 3.71810
# Epoch 319/500
# 42/42 [==============================] - 72s 2s/step - loss: 3.9701 - val_loss: 3.7187
#
# Epoch 00319: val_loss did not improve from 3.71810
# Epoch 320/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0336 - val_loss: 3.7124
#
# Epoch 00320: val_loss improved from 3.71810 to 3.71239, saving model to ssd300.h5
# Epoch 321/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0964 - val_loss: 3.7324
#
# Epoch 00321: val_loss did not improve from 3.71239
# Epoch 322/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1151 - val_loss: 3.7050
#
# Epoch 00322: val_loss improved from 3.71239 to 3.70502, saving model to ssd300.h5
# Epoch 323/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1757 - val_loss: 3.7071
#
# Epoch 00323: val_loss did not improve from 3.70502
# Epoch 324/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0310 - val_loss: 3.7283
#
# Epoch 00324: val_loss did not improve from 3.70502
# Epoch 325/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0596 - val_loss: 3.7118
#
# Epoch 00325: val_loss did not improve from 3.70502
# Epoch 326/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0931 - val_loss: 3.7106
#
# Epoch 00326: val_loss did not improve from 3.70502
# Epoch 327/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0947 - val_loss: 3.7240
#
# Epoch 00327: val_loss did not improve from 3.70502
# Epoch 328/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9790 - val_loss: 3.7274
#
# Epoch 00328: val_loss did not improve from 3.70502
# Epoch 329/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1509 - val_loss: 3.7434
#
# Epoch 00329: val_loss did not improve from 3.70502
# Epoch 330/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0023 - val_loss: 3.7474
#
# Epoch 00330: val_loss did not improve from 3.70502
# Epoch 331/500
# ...
#
# Epoch 00398: val_loss did not improve from 3.65909
# Epoch 399/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.9610 - val_loss: 3.6611
#
# Epoch 00399: val_loss did not improve from 3.65909
# Epoch 400/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9898 - val_loss: 3.6714
#
# Epoch 00400: val_loss did not improve from 3.65909
# Epoch 401/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0106 - val_loss: 3.6585
#
# Epoch 00401: val_loss improved from 3.65909 to 3.65851, saving model to ssd300.h5
# Epoch 402/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9874 - val_loss: 3.6624
#
# Epoch 00402: val_loss did not improve from 3.65851
# Epoch 403/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.1496 - val_loss: 3.6887
#
# Epoch 00403: val_loss did not improve from 3.65851
# Epoch 404/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9264 - val_loss: 3.6913
#
# Epoch 00404: val_loss did not improve from 3.65851
# Epoch 405/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9770 - val_loss: 3.6587
#
# Epoch 00405: val_loss did not improve from 3.65851
# Epoch 406/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9882 - val_loss: 3.6737
#
# Epoch 00406: val_loss did not improve from 3.65851
# Epoch 407/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.0719 - val_loss: 3.6508
#
# Epoch 00407: val_loss improved from 3.65851 to 3.65077, saving model to ssd300.h5
# Epoch 408/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8424 - val_loss: 3.6423
#
# Epoch 00408: val_loss improved from 3.65077 to 3.64235, saving model to ssd300.h5
# Epoch 409/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9916 - val_loss: 3.6567
#
# Epoch 00409: val_loss did not improve from 3.64235
# Epoch 410/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9303 - val_loss: 3.6577
#
# Epoch 00410: val_loss did not improve from 3.64235
# Epoch 411/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9863 - val_loss: 3.6352
#
# Epoch 00411: val_loss improved from 3.64235 to 3.63516, saving model to ssd300.h5
# Epoch 412/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9571 - val_loss: 3.6450
#
# Epoch 00412: val_loss did not improve from 3.63516
# Epoch 413/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9604 - val_loss: 3.6275
#
# Epoch 00413: val_loss improved from 3.63516 to 3.62750, saving model to ssd300.h5
# Epoch 414/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9028 - val_loss: 3.6499
#
# Epoch 00414: val_loss did not improve from 3.62750
# Epoch 415/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9298 - val_loss: 3.6375
#
# Epoch 00415: val_loss did not improve from 3.62750
# Epoch 416/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.7415 - val_loss: 3.6678
#
# Epoch 00416: val_loss did not improve from 3.62750
# Epoch 417/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9170 - val_loss: 3.6654
#
# Epoch 00417: val_loss did not improve from 3.62750
# Epoch 418/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.1610 - val_loss: 3.6646
#
# Epoch 00418: val_loss did not improve from 3.62750
# Epoch 419/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9996 - val_loss: 3.6683
#
# Epoch 00419: val_loss did not improve from 3.62750
# Epoch 420/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8296 - val_loss: 3.6907
#
# Epoch 00420: val_loss did not improve from 3.62750
# Epoch 421/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.7348 - val_loss: 3.6796
#
# Epoch 00421: val_loss did not improve from 3.62750
# Epoch 422/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.8895 - val_loss: 3.6555
#
# Epoch 00422: val_loss did not improve from 3.62750
# Epoch 423/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0529 - val_loss: 3.6949
#
# Epoch 00423: val_loss did not improve from 3.62750
# Epoch 424/500
# 42/42 [==============================] - 66s 2s/step - loss: 3.9897 - val_loss: 3.6725
#
# Epoch 00424: val_loss did not improve from 3.62750
# Epoch 425/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.7958 - val_loss: 3.6635
#
# Epoch 00425: val_loss did not improve from 3.62750
# Epoch 426/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9947 - val_loss: 3.6704
#
# Epoch 00426: val_loss did not improve from 3.62750
# Epoch 427/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8583 - val_loss: 3.6536
#
# Epoch 00427: val_loss did not improve from 3.62750
# Epoch 428/500
# 42/42 [==============================] - 73s 2s/step - loss: 3.9899 - val_loss: 3.6304
#
# Epoch 00428: val_loss did not improve from 3.62750
# Epoch 429/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0025 - val_loss: 3.6173
#
# Epoch 00429: val_loss improved from 3.62750 to 3.61734, saving model to ssd300.h5
# Epoch 430/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0553 - val_loss: 3.6690
#
# Epoch 00430: val_loss did not improve from 3.61734
# Epoch 431/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8960 - val_loss: 3.6173
#
# Epoch 00431: val_loss did not improve from 3.61734
# Epoch 432/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.7848 - val_loss: 3.6087
#
# Epoch 00432: val_loss improved from 3.61734 to 3.60870, saving model to ssd300.h5
# Epoch 433/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0102 - val_loss: 3.6182
#
# Epoch 00433: val_loss did not improve from 3.60870
# Epoch 434/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9331 - val_loss: 3.6617
#
# Epoch 00434: val_loss did not improve from 3.60870
# Epoch 435/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.1990 - val_loss: 3.6262
#
# Epoch 00435: val_loss did not improve from 3.60870
# Epoch 436/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9386 - val_loss: 3.6064
#
# Epoch 00436: val_loss improved from 3.60870 to 3.60635, saving model to ssd300.h5
# Epoch 437/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.9003 - val_loss: 3.6360
#
# Epoch 00437: val_loss did not improve from 3.60635
# Epoch 438/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9465 - val_loss: 3.6068
#
# Epoch 00438: val_loss did not improve from 3.60635
# Epoch 439/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0586 - val_loss: 3.6233
#
# Epoch 00439: val_loss did not improve from 3.60635
# Epoch 440/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.8175 - val_loss: 3.6395
#
# Epoch 00440: val_loss did not improve from 3.60635
# Epoch 441/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0063 - val_loss: 3.6299
#
# Epoch 00441: val_loss did not improve from 3.60635
# Epoch 442/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8738 - val_loss: 3.6451
#
# Epoch 00442: val_loss did not improve from 3.60635
# Epoch 443/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9076 - val_loss: 3.6175
#
# Epoch 00443: val_loss did not improve from 3.60635
# Epoch 444/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9383 - val_loss: 3.6318
#
# Epoch 00444: val_loss did not improve from 3.60635
# Epoch 445/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8900 - val_loss: 3.6286
#
# Epoch 00445: val_loss did not improve from 3.60635
# Epoch 446/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8088 - val_loss: 3.6043
#
# Epoch 00446: val_loss improved from 3.60635 to 3.60429, saving model to ssd300.h5
# Epoch 447/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.7241 - val_loss: 3.6175
#
# Epoch 00447: val_loss did not improve from 3.60429
# Epoch 448/500
# 42/42 [==============================] - 72s 2s/step - loss: 4.0560 - val_loss: 3.6074
#
# Epoch 00448: val_loss did not improve from 3.60429
# Epoch 449/500
# 42/42 [==============================] - 72s 2s/step - loss: 3.9160 - val_loss: 3.6117
#
# Epoch 00449: val_loss did not improve from 3.60429
# Epoch 450/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8822 - val_loss: 3.5780
#
# Epoch 00450: val_loss improved from 3.60429 to 3.57796, saving model to ssd300.h5
# Epoch 451/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9582 - val_loss: 3.5869
#
# Epoch 00451: val_loss did not improve from 3.57796
# Epoch 452/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9602 - val_loss: 3.6212
#
# Epoch 00452: val_loss did not improve from 3.57796
# Epoch 453/500
# 42/42 [==============================] - 73s 2s/step - loss: 4.1168 - val_loss: 3.6272
#
# Epoch 00453: val_loss did not improve from 3.57796
# Epoch 454/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9398 - val_loss: 3.6082
#
# Epoch 00454: val_loss did not improve from 3.57796
# Epoch 455/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9105 - val_loss: 3.5893
#
# Epoch 00455: val_loss did not improve from 3.57796
# Epoch 456/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0908 - val_loss: 3.5835
#
# Epoch 00456: val_loss did not improve from 3.57796
# Epoch 457/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9197 - val_loss: 3.6292
#
# Epoch 00457: val_loss did not improve from 3.57796
# Epoch 458/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.7911 - val_loss: 3.6132
#
# Epoch 00458: val_loss did not improve from 3.57796
# Epoch 459/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.8226 - val_loss: 3.6535
#
# Epoch 00459: val_loss did not improve from 3.57796
# Epoch 460/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9115 - val_loss: 3.6510
#
# Epoch 00460: val_loss did not improve from 3.57796
# Epoch 461/500
# 42/42 [==============================] - 72s 2s/step - loss: 3.8605 - val_loss: 3.6546
#
# Epoch 00461: val_loss did not improve from 3.57796
# Epoch 462/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9615 - val_loss: 3.6481
#
# Epoch 00462: val_loss did not improve from 3.57796
# Epoch 463/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0393 - val_loss: 3.6271
#
# Epoch 00463: val_loss did not improve from 3.57796
# Epoch 464/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0644 - val_loss: 3.6237
#
# Epoch 00464: val_loss did not improve from 3.57796
# Epoch 465/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.1047 - val_loss: 3.5943
#
# Epoch 00465: val_loss did not improve from 3.57796
# Epoch 466/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9739 - val_loss: 3.6143
#
# Epoch 00466: val_loss did not improve from 3.57796
# Epoch 467/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.6700 - val_loss: 3.6048
#
# Epoch 00467: val_loss did not improve from 3.57796
# Epoch 468/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.8335 - val_loss: 3.6177
#
# Epoch 00468: val_loss did not improve from 3.57796
# Epoch 469/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.8347 - val_loss: 3.5967
#
# Epoch 00469: val_loss did not improve from 3.57796
# Epoch 470/500
# 42/42 [==============================] - 72s 2s/step - loss: 3.8528 - val_loss: 3.6267
#
# Epoch 00470: val_loss did not improve from 3.57796
# Epoch 471/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9690 - val_loss: 3.6220
#
# Epoch 00471: val_loss did not improve from 3.57796
# Epoch 472/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.8050 - val_loss: 3.6261
#
# Epoch 00472: val_loss did not improve from 3.57796
# Epoch 473/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8940 - val_loss: 3.6301
#
# Epoch 00473: val_loss did not improve from 3.57796
# Epoch 474/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0421 - val_loss: 3.6442
#
# Epoch 00474: val_loss did not improve from 3.57796
# Epoch 475/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9625 - val_loss: 3.6499
#
# Epoch 00475: val_loss did not improve from 3.57796
# Epoch 476/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0013 - val_loss: 3.6189
#
# Epoch 00476: val_loss did not improve from 3.57796
# Epoch 477/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.9702 - val_loss: 3.6088
#
# Epoch 00477: val_loss did not improve from 3.57796
# Epoch 478/500
# 42/42 [==============================] - 71s 2s/step - loss: 4.0242 - val_loss: 3.6091
#
# Epoch 00478: val_loss did not improve from 3.57796
# Epoch 479/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.7950 - val_loss: 3.6049
#
# Epoch 00479: val_loss did not improve from 3.57796
# Epoch 480/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9485 - val_loss: 3.6206
#
# Epoch 00480: val_loss did not improve from 3.57796
# Epoch 481/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.9267 - val_loss: 3.5882
#
# Epoch 00481: val_loss did not improve from 3.57796
# Epoch 482/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9952 - val_loss: 3.6035
#
# Epoch 00482: val_loss did not improve from 3.57796
# Epoch 483/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8722 - val_loss: 3.6156
#
# Epoch 00483: val_loss did not improve from 3.57796
# Epoch 484/500
# 42/42 [==============================] - 69s 2s/step - loss: 4.0225 - val_loss: 3.6044
#
# Epoch 00484: val_loss did not improve from 3.57796
# Epoch 485/500
# 42/42 [==============================] - 72s 2s/step - loss: 3.9595 - val_loss: 3.6242
#
# Epoch 00485: val_loss did not improve from 3.57796
# Epoch 486/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8787 - val_loss: 3.6182
#
# Epoch 00486: val_loss did not improve from 3.57796
# Epoch 487/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9464 - val_loss: 3.6012
#
# Epoch 00487: val_loss did not improve from 3.57796
# Epoch 488/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8299 - val_loss: 3.6279
#
# Epoch 00488: val_loss did not improve from 3.57796
# Epoch 489/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.6716 - val_loss: 3.6065
#
# Epoch 00489: val_loss did not improve from 3.57796
# Epoch 490/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.7673 - val_loss: 3.6459
#
# Epoch 00490: val_loss did not improve from 3.57796
# Epoch 491/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.9306 - val_loss: 3.6167
#
# Epoch 00491: val_loss did not improve from 3.57796
# Epoch 492/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.8297 - val_loss: 3.6013
#
# Epoch 00492: val_loss did not improve from 3.57796
# Epoch 493/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.6505 - val_loss: 3.5893
#
# Epoch 00493: val_loss did not improve from 3.57796
# Epoch 494/500
# 42/42 [==============================] - 70s 2s/step - loss: 3.9525 - val_loss: 3.6154
#
# Epoch 00494: val_loss did not improve from 3.57796
# Epoch 495/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.8983 - val_loss: 3.5928
#
# Epoch 00495: val_loss did not improve from 3.57796
# Epoch 496/500
# 42/42 [==============================] - 69s 2s/step - loss: 3.7872 - val_loss: 3.5983
#
# Epoch 00496: val_loss did not improve from 3.57796
# Epoch 497/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.7664 - val_loss: 3.5981
#
# Epoch 00497: val_loss did not improve from 3.57796
# Epoch 498/500
# 42/42 [==============================] - 70s 2s/step - loss: 4.0076 - val_loss: 3.6037
#
# Epoch 00498: val_loss did not improve from 3.57796
# Epoch 499/500
# 42/42 [==============================] - 71s 2s/step - loss: 3.8304 - val_loss: 3.6410
#
# Epoch 00499: val_loss did not improve from 3.57796
# Epoch 500/500
# 42/42 [==============================] - 68s 2s/step - loss: 3.9334 - val_loss: 3.6334
#
# Epoch 00500: val_loss did not improve from 3.57796
# Epoch 00500: early stopping

# %%
plot_model(model,to_file='model_ssd300.png')

# %%
fig = plt.figure(figsize=(20,12))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc='upper right', prop={'size': 24})
fig.savefig('loss.png')

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=False,
                                         transformations=[resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                    'processed_labels',
                                                    'filenames',
                                                    'original_images',
                                                    'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples

batch_images, batch_labels, batch_filenames, original_images, original_annotations= next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
# 3: Make a prediction

y_pred = model.predict(batch_images)

# 4: Decode the raw prediction `y_pred`

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.45,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Ground truth boxes:\nclass, xmin, ymin, xmax, ymax")
print(batch_labels[i])
print("\nPredicted boxes:")
print('class, conf, xmin, ymin, xmax, ymax')
print(y_pred_decoded[i])
# Out:
# Image: data/Full/00000.ppm
#
# Ground truth boxes:
# class, xmin, ymin, xmax, ymax
# [[ 11 228 154 240 167]]
#
# Predicted boxes:
# class, conf, xmin, ymin, xmax, ymax
# []

# %%
# 5: Draw the predicted boxes onto the image

plt.figure(figsize=(20,12))
plt.imshow(batch_images[i])

current_axis = plt.gca()

colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist() # Set the colors for the bounding boxes
classes = pd.read_csv('data/classes.txt') # Just so we can print class names onto the image instead of IDs

# Draw the ground truth boxes in green (omit the label for more clarity)
for box in batch_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes.loc[int(box[0]),'class_name'])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    #current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

# Draw the predicted boxes in blue
for box in y_pred_decoded[i]:
    xmin = box[-4]
    ymin = box[-3]
    xmax = box[-2]
    ymax = box[-1]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes.loc[int(box[0]),'class_name'], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
